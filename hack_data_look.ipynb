# %%
import pandas as pd

# %%
value_code = pd.read_csv("data/world-values-survey/Code_book.csv")
value = pd.read_csv("data/world-values-survey/WVS_per_Country.csv")

# %%
value_code
# Out:
#               IDX  Variable  \
# 0         001_001      A001
# 1     001_001_001   A001_CO
# 2         001_002      A002
# 3     001_002_001   A002_CO
# 4         001_003      A003
# 5     001_003_001   A003_CO
# 6         001_004      A004
# 7     001_004_001   A004_CO
# 8         001_005      A005
# 9     001_005_001   A005_CO
# 10        001_006      A006
# 11    001_006_001   A006_CO
# 12        001_007      A007
# 13        001_008      A008
# 14        001_009      A009
# 15        001_010      A010
# 16        001_011      A011
# 17        001_012      A012
# 18        001_013      A013
# 19        001_014      A014
# 20        001_015      A015
# 21        001_016      A016
# 22        001_017      A017
# 23        001_018      A018
# 24        001_019      A019
# 25        001_020      A020
# 26        001_021      A021
# 27        001_022      A022
# 28        001_023      A023
# 29        001_024      A024
# ...           ...       ...
# 1390      016_031  ZMEN_031
# ...

# %%
value[:10]
# Out:
#       Country  Wave  S004           S006      S007      S007_01 S009 S009A  \
# 0     Albania     4   NaN     500.500000  112494.5   80480500.5   AL    AL
# 1     Albania     3   1.0  200500.000000   78594.0   80360500.0   AL    AL
# 2     Algeria     4   NaN     641.500780  113635.5  120480641.5   DZ    DZ
# 3     Algeria     6   NaN     600.500000  331699.5  120600600.5   DZ    DZ
# 4     Andorra     5   NaN     722.209372  171526.0  200600502.0   AD    AD
# 5  Azerbaijan     6   NaN     501.500000  272929.5  310600501.5   AZ    AZ
# 6  Azerbaijan     3   1.0  191001.500000   82094.5  310361001.5   AZ    AZ
# 7   Argentina     4   NaN     687.016406  114916.5  320480640.5   AR    AR
# 8   Argentina     2   NaN     501.500000   10808.5  320240501.5   AR    AR
# 9   Argentina     5   NaN     507.223553  172528.5  320600501.5   AR    AR
#
#          S010         S011     ...        Y012_Sd   Y013_Sd   Y014_Sd  \
# 0   80.278000  1411.442000     ...       0.312742  0.412060  0.215111
# ...

# %%
for g, n in value.groupby("")
